# %%
import numpy as np
import matplotlib.pyplot as plt

# 定义要拟合的函数为 sinx
def true_function(x):
    return np.sin(x)

# 基于ReLU的两层神经网络
class ReLU_Network:
    def __init__(self):
        # 权重初始化
        self.W1 = np.random.randn(1, 150).astype(np.float32) * np.sqrt(2/1)  # He初始化
        self.b1 = np.zeros(150, dtype=np.float32)
        self.W2 = np.random.randn(150, 1).astype(np.float32) * np.sqrt(2/100)
        self.b2 = np.zeros(1, dtype=np.float32)
    
    def forward(self, x):
        # 前向传播
        hidden_preactivation = np.dot(x, self.W1) + self.b1
        hidden_layer = np.maximum(0, hidden_preactivation)  # ReLU激活
        output = np.dot(hidden_layer, self.W2) + self.b2
        return output, hidden_layer, hidden_preactivation

# 生成训练集和测试集
num_train_samples = 3000
num_test_samples = 600
x_train = np.random.uniform(-2*np.pi, 2*np.pi, size=(num_train_samples, 1))
y_train = true_function(x_train) + np.random.normal(loc=0, scale=0.1, size=(num_train_samples, 1))
x_test = np.linspace(-2*np.pi, 2*np.pi, num_test_samples).reshape(-1, 1)
y_test = true_function(x_test)

# 转换数据类型
x_train = x_train.astype(np.float32)
y_train = y_train.astype(np.float32)
x_test = x_test.astype(np.float32)
y_test = y_test.astype(np.float32)

# 学习率衰减
def learning_rate_schedule(initial_lr, epoch, decay_rate=0.95, decay_steps=100):
    return initial_lr * (decay_rate ** (epoch / decay_steps))

# 训练模型
def train_model(model, x_train, y_train, epochs=2000, initial_learning_rate=0.001):
    losses = []
    for epoch in range(epochs):
        # 动态调整学习率
        learning_rate = learning_rate_schedule(initial_learning_rate, epoch)
        
        # 前向传播
        output, hidden_layer, hidden_preactivation = model.forward(x_train)
        
        # 计算损失
        loss = np.mean((output - y_train)**2)
        losses.append(loss)
        
        # 反向传播
        batch_size = x_train.shape[0]
        d_output = 2 * (output - y_train) / batch_size
        
        # 计算第二层梯度
        dW2 = np.dot(hidden_layer.T, d_output)
        db2 = np.sum(d_output, axis=0)
        
        # 反向传播到隐藏层
        d_hidden = np.dot(d_output, model.W2.T)
        d_preactivation = d_hidden * (hidden_preactivation > 0)  # ReLU导数
        
        # 计算第一层梯度
        dW1 = np.dot(x_train.T, d_preactivation)
        db1 = np.sum(d_preactivation, axis=0)
        
        # 参数更新
        model.W1 -= learning_rate * dW1
        model.b1 -= learning_rate * db1
        model.W2 -= learning_rate * dW2
        model.b2 -= learning_rate * db2
        
        if epoch % 100 == 0:
            print(f"Epoch {epoch:4d}, Loss: {loss:.4f}, Learning Rate: {learning_rate:.6f}")

# 测试模型
def test_model(model, x_test, y_test):
    output, _, _ = model.forward(x_test)
    test_loss = np.mean((output - y_test)**2)
    print(f"\nTest Loss: {test_loss:.4f}")

# 创建并训练模型
model = ReLU_Network()
train_model(model, x_train, y_train, epochs=3000, initial_learning_rate=0.001)
test_model(model, x_test, y_test)

# 可视化结果
plt.figure(figsize=(10, 6))
plt.scatter(x_train, y_train, color='blue', label='Train data')
plt.plot(x_test, y_test, color='green', linestyle='--', label='True function')
plt.plot(x_test, model(x_test), color='red', label='Predicted function')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Function approximation using ReLU network')
plt.legend()
plt.show()
# Out:
# Epoch 0, Loss: 556.2019
# Epoch 10, Loss: 37.5444
# Epoch 20, Loss: 12.6541
# Epoch 30, Loss: 14.2474
# Epoch 40, Loss: 2.7838
# Epoch 50, Loss: 1.5490
# Epoch 60, Loss: 1.2102
# Epoch 70, Loss: 0.6796
# Epoch 80, Loss: 0.4271
# Epoch 90, Loss: 0.3211
# Epoch 100, Loss: 0.2617
# Epoch 110, Loss: 0.2256
# Epoch 120, Loss: 0.2053
# Epoch 130, Loss: 0.1947
# Epoch 140, Loss: 0.1896
# Epoch 150, Loss: 0.1873
# Epoch 160, Loss: 0.1862
# Epoch 170, Loss: 0.1855
# Epoch 180, Loss: 0.1850
# Epoch 190, Loss: 0.1846
# Epoch 200, Loss: 0.1841
# Epoch 210, Loss: 0.1837
# Epoch 220, Loss: 0.1833
# Epoch 230, Loss: 0.1828
# Epoch 240, Loss: 0.1823
# Epoch 250, Loss: 0.1818
# Epoch 260, Loss: 0.1813
# Epoch 270, Loss: 0.1807
# Epoch 280, Loss: 0.1802
# Epoch 290, Loss: 0.1796
# Epoch 300, Loss: 0.1790
# Epoch 310, Loss: 0.1784
# Epoch 320, Loss: 0.1778
# Epoch 330, Loss: 0.1772
# Epoch 340, Loss: 0.1765
# Epoch 350, Loss: 0.1759
# Epoch 360, Loss: 0.1752
# Epoch 370, Loss: 0.1745
# Epoch 380, Loss: 0.1739
# Epoch 390, Loss: 0.1732
# Epoch 400, Loss: 0.1725
# Epoch 410, Loss: 0.1719
# Epoch 420, Loss: 0.1712
# Epoch 430, Loss: 0.1705
# Epoch 440, Loss: 0.1698
# Epoch 450, Loss: 0.1691
# Epoch 460, Loss: 0.1685
# Epoch 470, Loss: 0.1678
# Epoch 480, Loss: 0.1672
# Epoch 490, Loss: 0.1665
# Epoch 500, Loss: 0.1659
# Epoch 510, Loss: 0.1653
# Epoch 520, Loss: 0.1647
# Epoch 530, Loss: 0.1641
# Epoch 540, Loss: 0.1635
# Epoch 550, Loss: 0.1629
# Epoch 560, Loss: 0.1624
# Epoch 570, Loss: 0.1618
# Epoch 580, Loss: 0.1613
# Epoch 590, Loss: 0.1608
# Epoch 600, Loss: 0.1603
# Epoch 610, Loss: 0.1598
# Epoch 620, Loss: 0.1593
# Epoch 630, Loss: 0.1588
# Epoch 640, Loss: 0.1583
# Epoch 650, Loss: 0.1579
# Epoch 660, Loss: 0.1575
# Epoch 670, Loss: 0.1571
# Epoch 680, Loss: 0.1567
# Epoch 690, Loss: 0.1563
# Epoch 700, Loss: 0.1559
# Epoch 710, Loss: 0.1555
# Epoch 720, Loss: 0.1552
# Epoch 730, Loss: 0.1548
# Epoch 740, Loss: 0.1545
# Epoch 750, Loss: 0.1542
# Epoch 760, Loss: 0.1539
# Epoch 770, Loss: 0.1536
# Epoch 780, Loss: 0.1533
# Epoch 790, Loss: 0.1530
# Epoch 800, Loss: 0.1527
# Epoch 810, Loss: 0.1524
# Epoch 820, Loss: 0.1521
# Epoch 830, Loss: 0.1518
# Epoch 840, Loss: 0.1515
# Epoch 850, Loss: 0.1513
# Epoch 860, Loss: 0.1510
# Epoch 870, Loss: 0.1508
# Epoch 880, Loss: 0.1505
# Epoch 890, Loss: 0.1503
# Epoch 900, Loss: 0.1501
# Epoch 910, Loss: 0.1498
# Epoch 920, Loss: 0.1496
# Epoch 930, Loss: 0.1494
# Epoch 940, Loss: 0.1491
# Epoch 950, Loss: 0.1489
# Epoch 960, Loss: 0.1487
# Epoch 970, Loss: 0.1485
# Epoch 980, Loss: 0.1483
# Epoch 990, Loss: 0.1481
# Epoch 1000, Loss: 0.1479
# Epoch 1010, Loss: 0.1477
# Epoch 1020, Loss: 0.1475
# Epoch 1030, Loss: 0.1473
# Epoch 1040, Loss: 0.1471
# Epoch 1050, Loss: 0.1469
# Epoch 1060, Loss: 0.1468
# Epoch 1070, Loss: 0.1466
# Epoch 1080, Loss: 0.1464
# Epoch 1090, Loss: 0.1462
# Epoch 1100, Loss: 0.1461
# Epoch 1110, Loss: 0.1459
# Epoch 1120, Loss: 0.1457
# Epoch 1130, Loss: 0.1456
# Epoch 1140, Loss: 0.1454
# Epoch 1150, Loss: 0.1452
# Epoch 1160, Loss: 0.1451
# Epoch 1170, Loss: 0.1449
# Epoch 1180, Loss: 0.1448
# Epoch 1190, Loss: 0.1446
# Epoch 1200, Loss: 0.1444
# Epoch 1210, Loss: 0.1443
# Epoch 1220, Loss: 0.1441
# Epoch 1230, Loss: 0.1440
# Epoch 1240, Loss: 0.1438
# Epoch 1250, Loss: 0.1437
# Epoch 1260, Loss: 0.1435
# Epoch 1270, Loss: 0.1434
# Epoch 1280, Loss: 0.1432
# Epoch 1290, Loss: 0.1431
# Epoch 1300, Loss: 0.1429
# Epoch 1310, Loss: 0.1428
# Epoch 1320, Loss: 0.1426
# Epoch 1330, Loss: 0.1425
# Epoch 1340, Loss: 0.1424
# Epoch 1350, Loss: 0.1422
# Epoch 1360, Loss: 0.1421
# Epoch 1370, Loss: 0.1419
# Epoch 1380, Loss: 0.1418
# Epoch 1390, Loss: 0.1416
# Epoch 1400, Loss: 0.1415
# Epoch 1410, Loss: 0.1413
# Epoch 1420, Loss: 0.1412
# Epoch 1430, Loss: 0.1410
# Epoch 1440, Loss: 0.1409
# Epoch 1450, Loss: 0.1407
# Epoch 1460, Loss: 0.1406
# Epoch 1470, Loss: 0.1404
# Epoch 1480, Loss: 0.1403
# Epoch 1490, Loss: 0.1401
# Epoch 1500, Loss: 0.1400
# Epoch 1510, Loss: 0.1398
# Epoch 1520, Loss: 0.1396
# Epoch 1530, Loss: 0.1395
# Epoch 1540, Loss: 0.1393
# Epoch 1550, Loss: 0.1391
# Epoch 1560, Loss: 0.1390
# Epoch 1570, Loss: 0.1388
# Epoch 1580, Loss: 0.1386
# Epoch 1590, Loss: 0.1384
# Epoch 1600, Loss: 0.1383
# Epoch 1610, Loss: 0.1381
# Epoch 1620, Loss: 0.1379
# Epoch 1630, Loss: 0.1377
# Epoch 1640, Loss: 0.1375
# Epoch 1650, Loss: 0.1373
# Epoch 1660, Loss: 0.1371
# Epoch 1670, Loss: 0.1369
# Epoch 1680, Loss: 0.1367
# Epoch 1690, Loss: 0.1365
# Epoch 1700, Loss: 0.1363
# Epoch 1710, Loss: 0.1361
# Epoch 1720, Loss: 0.1359
# Epoch 1730, Loss: 0.1357
# Epoch 1740, Loss: 0.1355
# Epoch 1750, Loss: 0.1352
# Epoch 1760, Loss: 0.1350
# Epoch 1770, Loss: 0.1348
# Epoch 1780, Loss: 0.1345
# Epoch 1790, Loss: 0.1343
# Epoch 1800, Loss: 0.1341
# Epoch 1810, Loss: 0.1338
# Epoch 1820, Loss: 0.1336
# Epoch 1830, Loss: 0.1333
# Epoch 1840, Loss: 0.1331
# Epoch 1850, Loss: 0.1328
# Epoch 1860, Loss: 0.1325
# Epoch 1870, Loss: 0.1323
# Epoch 1880, Loss: 0.1320
# Epoch 1890, Loss: 0.1317
# Epoch 1900, Loss: 0.1314
# Epoch 1910, Loss: 0.1311
# Epoch 1920, Loss: 0.1308
# Epoch 1930, Loss: 0.1305
# Epoch 1940, Loss: 0.1302
# Epoch 1950, Loss: 0.1299
# Epoch 1960, Loss: 0.1296
# Epoch 1970, Loss: 0.1293
# Epoch 1980, Loss: 0.1290
# Epoch 1990, Loss: 0.1287
# Epoch 2000, Loss: 0.1283
# Epoch 2010, Loss: 0.1280
# Epoch 2020, Loss: 0.1277
# Epoch 2030, Loss: 0.1273
# Epoch 2040, Loss: 0.1270
# Epoch 2050, Loss: 0.1266
# Epoch 2060, Loss: 0.1262
# Epoch 2070, Loss: 0.1259
# Epoch 2080, Loss: 0.1255
# Epoch 2090, Loss: 0.1251
# Epoch 2100, Loss: 0.1247
# Epoch 2110, Loss: 0.1244
# Epoch 2120, Loss: 0.1240
# Epoch 2130, Loss: 0.1236
# Epoch 2140, Loss: 0.1232
# Epoch 2150, Loss: 0.1228
# Epoch 2160, Loss: 0.1223
# Epoch 2170, Loss: 0.1219
# Epoch 2180, Loss: 0.1215
# Epoch 2190, Loss: 0.1211
# Epoch 2200, Loss: 0.1206
# Epoch 2210, Loss: 0.1202
# Epoch 2220, Loss: 0.1198
# Epoch 2230, Loss: 0.1193
# Epoch 2240, Loss: 0.1189
# Epoch 2250, Loss: 0.1184
# Epoch 2260, Loss: 0.1179
# Epoch 2270, Loss: 0.1175
# Epoch 2280, Loss: 0.1170
# Epoch 2290, Loss: 0.1165
# Epoch 2300, Loss: 0.1161
# Epoch 2310, Loss: 0.1156
# Epoch 2320, Loss: 0.1151
# Epoch 2330, Loss: 0.1146
# Epoch 2340, Loss: 0.1141
# Epoch 2350, Loss: 0.1136
# Epoch 2360, Loss: 0.1131
# Epoch 2370, Loss: 0.1126
# Epoch 2380, Loss: 0.1122
# Epoch 2390, Loss: 0.1117
# Epoch 2400, Loss: 0.1112
# Epoch 2410, Loss: 0.1107
# Epoch 2420, Loss: 0.1102
# Epoch 2430, Loss: 0.1097
# Epoch 2440, Loss: 0.1092
# Epoch 2450, Loss: 0.1087
# Epoch 2460, Loss: 0.1082
# Epoch 2470, Loss: 0.1077
# Epoch 2480, Loss: 0.1072
# Epoch 2490, Loss: 0.1067
# Epoch 2500, Loss: 0.1062
# Epoch 2510, Loss: 0.1057
# Epoch 2520, Loss: 0.1052
# Epoch 2530, Loss: 0.1047
# Epoch 2540, Loss: 0.1042
# Epoch 2550, Loss: 0.1037
# Epoch 2560, Loss: 0.1032
# Epoch 2570, Loss: 0.1028
# Epoch 2580, Loss: 0.1023
# Epoch 2590, Loss: 0.1018
# Epoch 2600, Loss: 0.1013
# Epoch 2610, Loss: 0.1008
# Epoch 2620, Loss: 0.1004
# Epoch 2630, Loss: 0.0999
# Epoch 2640, Loss: 0.0995
# Epoch 2650, Loss: 0.0990
# Epoch 2660, Loss: 0.0986
# Epoch 2670, Loss: 0.0981
# Epoch 2680, Loss: 0.0977
# Epoch 2690, Loss: 0.0973
# Epoch 2700, Loss: 0.0969
# Epoch 2710, Loss: 0.0964
# Epoch 2720, Loss: 0.0960
# Epoch 2730, Loss: 0.0956
# Epoch 2740, Loss: 0.0952
# Epoch 2750, Loss: 0.0948
# Epoch 2760, Loss: 0.0944
# Epoch 2770, Loss: 0.0941
# Epoch 2780, Loss: 0.0937
# Epoch 2790, Loss: 0.0933
# Epoch 2800, Loss: 0.0930
# Epoch 2810, Loss: 0.0926
# Epoch 2820, Loss: 0.0923
# Epoch 2830, Loss: 0.0919
# Epoch 2840, Loss: 0.0916
# Epoch 2850, Loss: 0.0912
# Epoch 2860, Loss: 0.0909
# Epoch 2870, Loss: 0.0906
# Epoch 2880, Loss: 0.0903
# Epoch 2890, Loss: 0.0900
# Epoch 2900, Loss: 0.0897
# Epoch 2910, Loss: 0.0894
# Epoch 2920, Loss: 0.0891
# Epoch 2930, Loss: 0.0889
# Epoch 2940, Loss: 0.0886
# Epoch 2950, Loss: 0.0883
# Epoch 2960, Loss: 0.0881
# Epoch 2970, Loss: 0.0878
# Epoch 2980, Loss: 0.0876
# Epoch 2990, Loss: 0.0874
# Test Loss: 0.0803
